# %%
# %pip install roboflow ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Qgth79upN58d25jLRmkD")
project = rf.workspace("sliit-gvlap").project("acanthosis-nigricans-detection-xempk")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Acanthosis-Nigricans-Detection-1 in yolov11:: 100%|██████████| 1612/1612 [00:00<00:00, 2721.29it/s]
# Extracting Dataset Version Zip to Acanthosis-Nigricans-Detection-1 in yolov11:: 100%|██████████| 1612/1612 [00:00<00:00, 2721.29it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

model.train(
    data="data.yaml",
    epochs=15,
    imgsz=640,
    batch=16
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.191 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.168  Python-3.9.13 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
import os
import glob
from PIL import Image
import matplotlib.pyplot as plt
from ultralytics import YOLO


model = YOLO("runs/detect/train2/weights/best.pt")

test_images = glob.glob("Acanthosis-Nigricans-Detection-1/test/images/*")
if test_images:
    sample_image = test_images[0]
    print(f"Testing on: {sample_image}")
    
    results = model(sample_image)
    
    plt.figure(figsize=(12, 8))
    
    plt.subplot(1, 2, 1)
    img = Image.open(sample_image)
    plt.imshow(img)
    plt.title("Original Image")
    plt.axis('off')
    
    plt.subplot(1, 2, 2)
    result_img = results[0].plot()
    plt.imshow(result_img)
    plt.title("Prediction")
    plt.axis('off')
    
    plt.tight_layout()
    plt.show()
    
    for r in results:
        print(f"\nDetections found: {len(r.boxes)}")
        if len(r.boxes) > 0:
            for i, box in enumerate(r.boxes):
                cls = int(box.cls[0])
                conf = float(box.conf[0])
                class_name = model.names[cls]
                print(f"Detection {i+1}: {class_name} (confidence: {conf:.2f})")
        else:
            print("No detections found")
else:
    print("No test images found!")
# Out:
# Testing on: Acanthosis-Nigricans-Detection-1/test/images\100_jpg.rf.28456ab4ee6c8915ec74ac2efb258426.jpg
#
# image 1/1 c:\Users\Dell\Documents\GitHub\GlucoZap\ml\Acanthosis_Nigricans_Detection\Acanthosis-Nigricans-Detection-1\test\images\100_jpg.rf.28456ab4ee6c8915ec74ac2efb258426.jpg: 640x640 1 Acanthosis Nigricans, 11.6ms
# Speed: 3.7ms preprocess, 11.6ms inference, 128.9ms postprocess per image at shape (1, 3, 640, 640)
# Detections found: 1
# Detection 1: Acanthosis Nigricans (confidence: 0.48)
